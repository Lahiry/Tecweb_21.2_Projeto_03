# %% [markdown]
# # EDA - Projeto 3 TecWeb 2021.2

# %% [markdown]
# Os datasets que estamos trabalhando foram dados extraídos do site Lopes e Vida real, com o auxílio de ferramentas de scrapping, como Beautiful Soup e Selenium
#
# No processo de extração, coletemos os seguintes dados
#
# > <b>Imóvel</b>: Tipo de imóvel
#
# > <b>Preço</b>: Preço por noite, em reais
#
# > <b>Aluguel</b>:
#
# > <b>Bairro</b>: Localização
#
# > <b>Área</b>: Metragem
#
# > <b>Quartos</b>: Número de quartos
#
# > <b>Banheiros</b>: Número de banheiros
#
# > <b>Vagas</b>: Número de vagas

# %%
# importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ___
# # Análise Preliminar

# %%
df_lopes = pd.read_csv("./data/dados_anuncios_lopes_imoveis.csv", decimal=",")
df_vr = pd.read_csv("./data/Viva_real.csv")

# %%
df_lopes.head(10)
# Out:
#         Imóvel Preço (R$) Aluguel (R$)             Bairro     Área  Quartos  \
# 0  Apartamento      2.478        1.750            Santana    62m²         2
# 1  Apartamento      3.020        2.300            Santana    72m²         2
# 2   Condomínio     59.600       50.000  Alto Da Boa Vista   594m²         4
# 3  Apartamento     64.990       50.000  Alto De Pinheiros   644m²         4
# 4  Apartamento     18.809       13.000      Vila Madalena   280m²         4
# 5      Sobrado     19.400       18.000            Santana   597m²         4
# 6  Apartamento      4.380        3.000            Santana    78m²         3
# 7  Apartamento      2.808        2.000         Bela Vista    48m²         1
# 8  Apartamento      4.383        3.300       Vila Mariana   100m²         3
# 9        Salas      2.594        1.400     Jardim América    40m²         0
#
#    Banheiros  Vagas
# 0          2      1
# 1          2      1
# 2          6      4
# 3          6      8
# 4          5      5
# 5          7      6
# 6          2      2
# 7          1      1
# 8          3      1
# 9          1      0

# %%
df_vr.head(10)
# Out:
#    Unnamed: 0         Imóvel  Preço (R$)  Aluguel (R$)               Bairro  \
# 0           0    Apartamento         590          1100         Vila Andrade
# 1           1    Apartamento        1190          7750           Itaim Bibi
# 2           2  Sala/Conjunto           0          2500             Brooklin
# 3           3    Apartamento         651          1500      Vila Água Funda
# 4           4    Apartamento        1150          3200         Vila Mariana
# 5           5    Apartamento         600          8500  Vila Nova Conceição
# 6           6    Apartamento         850          5900               Sumaré
# 7           7    Apartamento         450          3200         Indianópolis
# 8           8    Apartamento           0          1350        Vila Madalena
# 9           9    Apartamento         536          2800             Brooklin
#
#    Área (m²)  Quartos  Banheiros  Vagas
# 0         35        1          1      1
# 1        117        2          2      1
# 2         70        0          2      3
# 3         75        2          2      1
# 4        110        3          2      1
# 5        100        3          3      1
# 6         74        2          3      2
# 7         36        1          1      0
# 8         24        1          1      0
# 9         47        1          1      1

# %%
print(df_lopes.info())
print("")
print(df_vr.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Imóvel        429 non-null    object
#  1   Preço (R$)    429 non-null    object
#  2   Aluguel (R$)  429 non-null    object
#  3   Bairro        429 non-null    object
#  4   Área          429 non-null    object
#  5   Quartos       429 non-null    int64
#  6   Banheiros     429 non-null    int64
#  7   Vagas         429 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 26.9+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8964 entries, 0 to 8963
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8964 non-null   int64
#  1   Imóvel        8964 non-null   object
#  2   Preço (R$)    8964 non-null   int64
#  3   Aluguel (R$)  8964 non-null   int64
#  4   Bairro        8964 non-null   object
#  5   Área (m²)     8964 non-null   int64
#  6   Quartos       8964 non-null   int64
#  7   Banheiros     8964 non-null   int64
#  8   Vagas         8964 non-null   int64
# dtypes: int64(7), object(2)
# memory usage: 630.4+ KB
# None

# %% [markdown]
# ___
# # Tratamento dos dados

# %%
df_vr.drop(columns=df_vr.columns[0], inplace = True)

# %%
df_vr
# Out:
#              Imóvel  Preço (R$)  Aluguel (R$)           Bairro  Área (m²)  \
# 0       Apartamento         590          1100     Vila Andrade         35
# 1       Apartamento        1190          7750       Itaim Bibi        117
# 2     Sala/Conjunto           0          2500         Brooklin         70
# 3       Apartamento         651          1500  Vila Água Funda         75
# 4       Apartamento        1150          3200     Vila Mariana        110
# ...             ...         ...           ...              ...        ...
# 8959    Apartamento         250          1051        Liberdade         30
# 8960  Sala/Conjunto           0          2800    Santa Cecília         88
# 8961    Apartamento         650          1700       Consolação         50
# 8962    Apartamento         925          3999       Itaim Bibi         95
# 8963           Casa        2350           950     Jardim Japão         40
#
#       Quartos  Banheiros  Vagas
# 0           1          1      1
# 1           2          2      1
# 2           0          2      3
# 3           2          2      1
# 4           3          2      1
# ...       ...        ...    ...
# 8959        1          1      0
# 8960        0          2      0
# 8961        2          1      1
# 8962        2          1      0
# 8963        1          1      0
#
# [8964 rows x 8 columns]

# %%
df_lopes["Área"] = df_lopes["Área"].apply(lambda s : s.replace("m²", ""))

# %%
df_lopes
# Out:
#            Imóvel Preço (R$) Aluguel (R$)             Bairro   Área  Quartos  \
# 0     Apartamento      2.478        1.750            Santana    62         2
# 1     Apartamento      3.020        2.300            Santana    72         2
# 2      Condomínio     59.600       50.000  Alto Da Boa Vista   594         4
# 3     Apartamento     64.990       50.000  Alto De Pinheiros   644         4
# 4     Apartamento     18.809       13.000      Vila Madalena   280         4
# ..            ...        ...          ...                ...    ...      ...
# 424   Apartamento      2.222        1.800     Vila Anastácio    48         2
# 425   Apartamento     13.261       10.000     Jardim América   180         4
# 426          Casa     25.900       20.000  Alto Da Boa Vista   587         4
# 427  Casa de vila      1.300        1.300            Santana    60         1
# 428   Apartamento     14.660       10.000              Moema   300         3
#
#      Banheiros  Vagas
# 0            2      1
# 1            2      1
# 2            6      4
# 3            6      8
# 4            5      5
# ..         ...    ...
# 424          1      1
# 425          3      2
# 426          1      4
# 427          1      0
# 428          4      2
#
# [429 rows x 8 columns]

# %%
to_numeric = ["Preço (R$)", "Aluguel (R$)", "Área" ]

for column in to_numeric:
    try:
        df_lopes[column] = df_lopes[column].astype(str).astype(int)
    except:
        df_lopes[column] = df_lopes[column].astype(str).astype(float)

# %%
print(df_lopes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Imóvel        429 non-null    object
#  1   Preço (R$)    429 non-null    float64
#  2   Aluguel (R$)  429 non-null    float64
#  3   Bairro        429 non-null    object
#  4   Área          429 non-null    int32
#  5   Quartos       429 non-null    int64
#  6   Banheiros     429 non-null    int64
#  7   Vagas         429 non-null    int64
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 25.3+ KB
# None

# %% [markdown]
# ___
# # Análise Exploratória

# %% [markdown]
# ## 1. Estatísticas

# %%
plt.figure(figsize = (30,10))

plt.subplot(1,2,1)
ax = sns.heatmap(df_lopes.describe().T, 
                 cmap = 'Blues', 
                annot = True, fmt = '.1f', 
                linewidths = 5, cbar = False, 
                annot_kws={"size": 16})
ax.set_title('Describe dos dados da Lopes', fontsize = 18)
plt.xticks(size = 12)
plt.yticks(size = 12, rotation = 0);

plt.subplot(1,2,2)
ax = sns.heatmap(df_vr.describe().T, 
                 cmap = 'CMRmap_r', 
                annot = True, fmt = '.1f', 
                linewidths = 5, cbar = False, 
                annot_kws={"size": 16})
ax.set_title('Describe dos dados da VR', fontsize = 18)
plt.xticks(size = 12)
plt.yticks(size = 12, rotation = 0);

# %%
plt.figure(figsize=(30,12))

plt.subplot(1,2,1)
ax1 = sns.distplot(df_lopes['Aluguel (R$)'])
ax1.set_title('Histograma dos Aluguéis da Lopes', fontsize = 16)
ax1.set_ylabel('Frequência')
ax1.set_xlabel('Aluguel (R$)')

plt.subplot(1,2,2)
ax2 = sns.boxplot(data = df_lopes['Aluguel (R$)'], orient='h')
ax2.set_title('Boxplot do Aluguel',fontsize = 16)
ax2.set_xlabel('Aluguel (R$)')

plt.show()

# %% [markdown]
# Observamos que a variável `Aluguel`, dos dados obtidos da Lopes, possi um compartamento assimétrico a direita, o que faz sentido, já que é normal possuir mais anúncios baratos e acessíveis para a maioria dos usuários, tendo menos anúncios caros, reservados àqueles que queiram pagar em um lugar mais luxuoso. O bloxplot, a direita, demonstra justamente essa concentração do nosso intervalo interquatílico mais a esquerda. Também, podemos observar esses lugares mais luxuosos em forma de outliers.

# %%
plt.figure(figsize=(30,12))

plt.subplot(1,2,1)
ax1 = sns.distplot(df_vr['Aluguel (R$)'])
ax1.set_title('Histograma dos Alguéis da Lopes', fontsize = 16)
ax1.set_ylabel('Frequência')
ax1.set_xlabel('Aluguel (R$)')

plt.subplot(1,2,2)
ax2 = sns.boxplot(data = df_vr['Aluguel (R$)'], orient='h')
ax2.set_title('Boxplot do Aluguel',fontsize = 16)
ax2.set_xlabel('Aluguel (R$)')

plt.show()

# %% [markdown]
# Já nos dados da Vida Real, temos o mesmo padrão repetido. O que era de se esperar, pois ambas empresas trabalham no mesmo segmento.

# %%
group_bairro_preco = df_lopes.groupby(by = 'Bairro').mean()['Aluguel (R$)'].sort_values(ascending = False)

# %%
ax = sns.barplot(x = group_bairro_preco.index, y = group_bairro_preco.values)
ax.set_title('Média dos aluguéis por Bairro', fontsize = 16)
ax.set_ylabel('Média dos Preços')
ax.set_xlabel('Bairros')
ax.figure.set_size_inches(20,6)
plt.xticks(rotation=80);

# %% [markdown]
# Agrupamos os dados da Lopes a partir da variável `Bairros`. Em seguida, calculamos o aluguel médio para cada bairro, e podemos observar que a *Casa Verde* possui os anúncios mais caros, seguido do *Jardim Europa* e *Centro*.

# %%
group_bairro_preco = df_vr.groupby(by = 'Bairro').mean()['Aluguel (R$)'].sort_values(ascending = False)

# %%
ax = sns.barplot(x = group_bairro_preco.index, y = group_bairro_preco.values)
ax.set_title('Média dos aluguéis por Bairro', fontsize = 16)
ax.set_ylabel('Média dos Preços')
ax.set_xlabel('Bairros')
ax.figure.set_size_inches(20,6)
plt.xticks(rotation=80);

# %% [markdown]
# Agora, nos dados da VR, temos que o bairro com o alguel mais caro está na região de Jardim Paulista, seguindo a Vila Nova Conceição e Itaim Bibi.

# %%
plt.figure(figsize = (12,6))
ax = sns.heatmap(df_lopes.corr(), 
                 cmap = 'Blues', 
                annot = True, fmt = '.1f', 
                linewidths = 5, cbar = False, 
                annot_kws={"size": 16})
ax.set_title('Correlações', fontsize = 18)
plt.xticks(size = 12, rotation = 0)
plt.yticks(size = 12, rotation = 0);

# %%
plt.figure(figsize = (12,6))
ax = sns.heatmap(df_lopes.corr(), 
                 cmap = 'CMRmap_r', 
                annot = True, fmt = '.1f', 
                linewidths = 5, cbar = False, 
                annot_kws={"size": 16})
ax.set_title('Correlações', fontsize = 18)
plt.xticks(size = 12, rotation = 0)
plt.yticks(size = 12, rotation = 0);
