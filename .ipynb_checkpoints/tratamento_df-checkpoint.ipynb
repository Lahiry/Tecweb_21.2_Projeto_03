# %%
import pandas as pd

# %%
dados = pd.read_csv('dados_anuncios_lopes_imoveis.csv', decimal=',')

# %%
dados.head(10)
# Out:
#         Imóvel  Preço (R$)  Aluguel (R$)             Bairro     Área  Quartos  \
# 0  Apartamento        2478          1750            Santana    62m²         2
# 1  Apartamento        3020          2300            Santana    72m²         2
# 2   Condomínio       59600         50000  Alto Da Boa Vista   594m²         4
# 3  Apartamento       64989         50000  Alto De Pinheiros   644m²         4
# 4  Apartamento       18809         13000      Vila Madalena   280m²         4
# 5      Sobrado       19400         18000            Santana   597m²         4
# 6  Apartamento        4380          3000            Santana    78m²         3
# 7  Apartamento        2808          2000         Bela Vista    48m²         1
# 8  Apartamento        4383          3300       Vila Mariana   100m²         3
# 9        Salas        2594          1400     Jardim América    40m²         0
#
#    Banheiros  Vagas
# 0          2      1
# 1          2      1
# 2          6      4
# 3          6      8
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Imóvel        429 non-null    object
#  1   Preço (R$)    429 non-null    object
#  2   Aluguel (R$)  429 non-null    object
#  3   Bairro        429 non-null    object
#  4   Área          429 non-null    object
#  5   Quartos       429 non-null    int64
#  6   Banheiros     429 non-null    int64
#  7   Vagas         429 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 26.9+ KB

# %%
dados['Aluguel (R$)'] = (dados['Aluguel (R$)'].astype(float)*1000).astype(int)

# %%
dados.head()
# Out:
#         Imóvel  Preço (R$)  Aluguel (R$)             Bairro     Área  Quartos  \
# 0  Apartamento        2478          1750            Santana    62m²         2
# 1  Apartamento        3020          2300            Santana    72m²         2
# 2   Condomínio       59600         50000  Alto Da Boa Vista   594m²         4
# 3  Apartamento       64989         50000  Alto De Pinheiros   644m²         4
# 4  Apartamento       18809         13000      Vila Madalena   280m²         4
#
#    Banheiros  Vagas
# 0          2      1
# 1          2      1
# 2          6      4
# 3          6      8
# 4          5      5

# %%
dados['Área'] = dados['Área'].str.replace('m²', '')

# %%
dados.rename({'Área': 'Área (m²)'}, axis=1, inplace=True)

# %%
dados.head(10)
# Out:
#         Imóvel  Preço (R$)  Aluguel (R$)             Bairro Área (m²)  \
# 0  Apartamento        2478          1750            Santana       62
# 1  Apartamento        3020          2300            Santana       72
# 2   Condomínio       59600         50000  Alto Da Boa Vista      594
# 3  Apartamento       64989         50000  Alto De Pinheiros      644
# 4  Apartamento       18809         13000      Vila Madalena      280
# 5      Sobrado       19400         18000            Santana      597
# 6  Apartamento        4380          3000            Santana       78
# 7  Apartamento        2808          2000         Bela Vista       48
# 8  Apartamento        4383          3300       Vila Mariana      100
# 9        Salas        2594          1400     Jardim América       40
#
#    Quartos  Banheiros  Vagas
# 0        2          2      1
# 1        2          2      1
# 2        4          6      4
# 3        4          6      8
# 4        4          5      5
# ...

# %%
dados.to_csv('dados_anuncios_lopes_imoveis.csv', index=False)
